# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
import pandas as pd
import re
import logging
from keras.preprocessing.text import Tokenizer, tokenizer_from_json
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
import pickle
import json

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Device and hyperparameters
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
logger.info(f'Using device: {DEVICE}')

BATCH_SIZE = 8
MAX_TEXT_LEN = 128
MAX_SUMMARY_LEN = 32
EPOCHS = 10
LEARNING_RATE = 1e-4
EMBEDDING_DIM = 256
HIDDEN_DIM = 512
# Out:
# INFO:__main__:Using device: cuda

# %%
def normalize_arabic(text):
    if pd.isna(text) or not isinstance(text, str):
        return ""
    text = re.sub(r'[إأآا]', 'ا', text)
    text = re.sub(r'ى', 'ي', text)
    text = re.sub(r'ؤ', 'و', text)
    text = re.sub(r'ئ', 'ي', text)
    text = re.sub(r'ة', 'ه', text)
    text = re.sub(r'[ًٌٍَُِّْ]', '', text)  # Remove diacritics
    text = re.sub(r'[^\u0600-\u06FF\s]', '', text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

def load_and_preprocess_data():
    logger.info("Loading and preprocessing dataset...")
    df = pd.read_excel("Text summarization dataset.xlsx")
    df = df.iloc[1:].reset_index(drop=True)
    df.columns = ['summary', 'text']
    df = df.dropna(subset=['summary', 'text'])
    df['text'] = df['text'].astype(str)
    df['summary'] = df['summary'].astype(str)
    df = df[~df['text'].isin(['nan', ''])]
    df = df[~df['summary'].isin(['nan', ''])]
    df['text'] = df['text'].apply(normalize_arabic)
    df['summary'] = df['summary'].apply(normalize_arabic)
    df = df[df['text'].str.len() > 0]
    df = df[df['summary'].str.len() > 0]
    logger.info(f"Final dataset shape: {df.shape}")
    return df

# %%
def prepare_sequences(texts, summaries):
    # Combine all texts and summaries to build vocabulary
    all_texts = list(texts) + list(summaries)
    
    # Create tokenizer with no OOV token
    tokenizer = Tokenizer(filters='', oov_token=None)
    tokenizer.fit_on_texts(all_texts)
    
    # Add special tokens
    tokenizer.word_index['<sos>'] = len(tokenizer.word_index) + 1
    tokenizer.word_index['<eos>'] = len(tokenizer.word_index) + 1
    
    # Convert texts to sequences
    text_sequences = tokenizer.texts_to_sequences(texts)
    summary_sequences = tokenizer.texts_to_sequences(summaries)
    
    # Add <sos> and <eos> to summaries
    summary_sequences = [[tokenizer.word_index['<sos>']] + seq + [tokenizer.word_index['<eos>']] 
                        for seq in summary_sequences]
    
    # Pad sequences
    text_padded = pad_sequences(text_sequences, maxlen=MAX_TEXT_LEN, padding='post')
    summary_padded = pad_sequences(summary_sequences, maxlen=MAX_SUMMARY_LEN, padding='post')
    
    return tokenizer, text_padded, summary_padded

# %%
class SummarizationDataset(Dataset):
    def __init__(self, texts, summaries):
        self.texts = torch.tensor(texts, dtype=torch.long)
        self.summaries = torch.tensor(summaries, dtype=torch.long)
    def __len__(self):
        return len(self.texts)
    def __getitem__(self, idx):
        return self.texts[idx], self.summaries[idx]

class Encoder(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=0)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
    def forward(self, x):
        embedded = self.embedding(x)
        outputs, (hidden, cell) = self.lstm(embedded)
        return outputs, (hidden, cell)

class Decoder(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=0)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, vocab_size)
    def forward(self, x, hidden, cell):
        embedded = self.embedding(x)
        output, (hidden, cell) = self.lstm(embedded, (hidden, cell))
        prediction = self.fc(output)
        return prediction, hidden, cell

class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
    def forward(self, src, trg, teacher_forcing_ratio=0.5):
        batch_size = src.shape[0]
        trg_len = trg.shape[1]
        trg_vocab_size = self.decoder.fc.out_features
        outputs = torch.zeros(batch_size, trg_len, trg_vocab_size).to(DEVICE)
        _, (hidden, cell) = self.encoder(src)
        input = trg[:, 0].unsqueeze(1)
        for t in range(1, trg_len):
            output, hidden, cell = self.decoder(input, hidden, cell)
            outputs[:, t] = output.squeeze(1)
            teacher_force = torch.rand(1).item() < teacher_forcing_ratio
            top1 = output.argmax(2)
            input = trg[:, t].unsqueeze(1) if teacher_force else top1
        return outputs

# %%
from torch.cuda.amp import autocast, GradScaler

def train_model(model, train_loader, optimizer, criterion, scaler, epoch):
    model.train()
    epoch_loss = 0
    
    for batch_idx, (src, trg) in enumerate(train_loader):
        src, trg = src.to(DEVICE), trg.to(DEVICE)
        
        optimizer.zero_grad()
        with autocast():
            output = model(src, trg)
            
            # Reshape output and target for loss calculation
            output = output[:, 1:].reshape(-1, output.shape[-1])
            trg = trg[:, 1:].reshape(-1)
            
            loss = criterion(output, trg)
        
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        
        epoch_loss += loss.item()
        
        if batch_idx % 100 == 0:
            logger.info(f'Epoch: {epoch}, Batch: {batch_idx}, Loss: {loss.item():.4f}')
    
    return epoch_loss / len(train_loader)

# %%
def main():
    # Load and preprocess data
    df = load_and_preprocess_data()
    
    # Prepare sequences
    tokenizer, text_padded, summary_padded = prepare_sequences(df['text'], df['summary'])
    vocab_size = len(tokenizer.word_index) + 1
    
    # Split data
    train_text, val_text, train_summary, val_summary = train_test_split(
        text_padded, summary_padded, test_size=0.1, random_state=42
    )
    
    # Create datasets and dataloaders
    train_dataset = SummarizationDataset(train_text, train_summary)
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    
    # Initialize model
    encoder = Encoder(vocab_size, EMBEDDING_DIM, HIDDEN_DIM).to(DEVICE)
    decoder = Decoder(vocab_size, EMBEDDING_DIM, HIDDEN_DIM).to(DEVICE)
    model = Seq2Seq(encoder, decoder).to(DEVICE)
    
    # Initialize optimizer and loss
    criterion = nn.CrossEntropyLoss(ignore_index=0)
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
    
    # Initialize gradient scaler for mixed precision
    scaler = GradScaler()
    
    # Training loop
    for epoch in range(EPOCHS):
        train_loss = train_model(model, train_loader, optimizer, criterion, scaler, epoch)
        logger.info(f'Epoch: {epoch}, Train Loss: {train_loss:.4f}')
        
        # Save model
        torch.save(model.state_dict(), f'arabic_summarizer_epoch_{epoch}.pt')
    
    return model, tokenizer

# Run training
model, tokenizer = main()
# Out:
# INFO:__main__:Loading and preprocessing dataset...
# INFO:__main__:Final dataset shape: (29189, 2)
# C:\Users\Azooo\AppData\Local\Temp\ipykernel_5608\2858627687.py:28: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# C:\Users\Azooo\AppData\Local\Temp\ipykernel_5608\2949670534.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# INFO:__main__:Epoch: 0, Batch: 0, Loss: 12.4969
# INFO:__main__:Epoch: 0, Batch: 100, Loss: 10.2372
# INFO:__main__:Epoch: 0, Batch: 200, Loss: 9.2109
# INFO:__main__:Epoch: 0, Batch: 300, Loss: 9.0862
# INFO:__main__:Epoch: 0, Batch: 400, Loss: 9.0793
# INFO:__main__:Epoch: 0, Batch: 500, Loss: 8.7775
# INFO:__main__:Epoch: 0, Batch: 600, Loss: 8.1185
# INFO:__main__:Epoch: 0, Batch: 700, Loss: 8.6943
# INFO:__main__:Epoch: 0, Batch: 800, Loss: 9.0193
# INFO:__main__:Epoch: 0, Batch: 900, Loss: 8.1800
# INFO:__main__:Epoch: 0, Batch: 1000, Loss: 7.8812
# INFO:__main__:Epoch: 0, Batch: 1100, Loss: 8.6961
# INFO:__main__:Epoch: 0, Batch: 1200, Loss: 8.3987
# INFO:__main__:Epoch: 0, Batch: 1300, Loss: 9.2121
# INFO:__main__:Epoch: 0, Batch: 1400, Loss: 8.4821
# INFO:__main__:Epoch: 0, Batch: 1500, Loss: 8.3253
# INFO:__main__:Epoch: 0, Batch: 1600, Loss: 8.3474
# INFO:__main__:Epoch: 0, Batch: 1700, Loss: 8.3614
# INFO:__main__:Epoch: 0, Batch: 1800, Loss: 8.2469
# INFO:__main__:Epoch: 0, Batch: 1900, Loss: 8.8754
# INFO:__main__:Epoch: 0, Batch: 2000, Loss: 8.5694
# INFO:__main__:Epoch: 0, Batch: 2100, Loss: 8.4720
# INFO:__main__:Epoch: 0, Batch: 2200, Loss: 8.4150
# INFO:__main__:Epoch: 0, Batch: 2300, Loss: 8.4716
# INFO:__main__:Epoch: 0, Batch: 2400, Loss: 8.6515
# INFO:__main__:Epoch: 0, Batch: 2500, Loss: 8.1658
# INFO:__main__:Epoch: 0, Batch: 2600, Loss: 8.3847
# INFO:__main__:Epoch: 0, Batch: 2700, Loss: 8.4615
# INFO:__main__:Epoch: 0, Batch: 2800, Loss: 8.5947
# INFO:__main__:Epoch: 0, Batch: 2900, Loss: 8.1420
# INFO:__main__:Epoch: 0, Batch: 3000, Loss: 8.8118
# INFO:__main__:Epoch: 0, Batch: 3100, Loss: 8.2409
# INFO:__main__:Epoch: 0, Batch: 3200, Loss: 8.8188
# INFO:__main__:Epoch: 0, Train Loss: 8.6644
# INFO:__main__:Epoch: 1, Batch: 0, Loss: 8.6525
# INFO:__main__:Epoch: 1, Batch: 100, Loss: 8.0911
# INFO:__main__:Epoch: 1, Batch: 200, Loss: 7.9035
# INFO:__main__:Epoch: 1, Batch: 300, Loss: 7.9856
# INFO:__main__:Epoch: 1, Batch: 400, Loss: 8.5912
# INFO:__main__:Epoch: 1, Batch: 500, Loss: 8.3171
# INFO:__main__:Epoch: 1, Batch: 600, Loss: 8.3682
# INFO:__main__:Epoch: 1, Batch: 700, Loss: 8.0479
# INFO:__main__:Epoch: 1, Batch: 800, Loss: 8.0821
# INFO:__main__:Epoch: 1, Batch: 900, Loss: 8.2329
# INFO:__main__:Epoch: 1, Batch: 1000, Loss: 8.1799
# INFO:__main__:Epoch: 1, Batch: 1100, Loss: 8.4157
# INFO:__main__:Epoch: 1, Batch: 1200, Loss: 7.4126
# INFO:__main__:Epoch: 1, Batch: 1300, Loss: 8.0134
# INFO:__main__:Epoch: 1, Batch: 1400, Loss: 7.9822
# INFO:__main__:Epoch: 1, Batch: 1500, Loss: 8.5189
# INFO:__main__:Epoch: 1, Batch: 1600, Loss: 8.1840
# INFO:__main__:Epoch: 1, Batch: 1700, Loss: 8.1990
# INFO:__main__:Epoch: 1, Batch: 1800, Loss: 7.5208
# INFO:__main__:Epoch: 1, Batch: 1900, Loss: 8.0160
# INFO:__main__:Epoch: 1, Batch: 2000, Loss: 7.9551
# INFO:__main__:Epoch: 1, Batch: 2100, Loss: 8.2646
# INFO:__main__:Epoch: 1, Batch: 2200, Loss: 7.8330
# INFO:__main__:Epoch: 1, Batch: 2300, Loss: 8.2214
# INFO:__main__:Epoch: 1, Batch: 2400, Loss: 7.4001
# INFO:__main__:Epoch: 1, Batch: 2500, Loss: 7.4586
# INFO:__main__:Epoch: 1, Batch: 2600, Loss: 8.1054
# INFO:__main__:Epoch: 1, Batch: 2700, Loss: 7.6944
# INFO:__main__:Epoch: 1, Batch: 2800, Loss: 7.8649
# INFO:__main__:Epoch: 1, Batch: 2900, Loss: 8.0422
# INFO:__main__:Epoch: 1, Batch: 3000, Loss: 7.2793
# INFO:__main__:Epoch: 1, Batch: 3100, Loss: 7.6181
# INFO:__main__:Epoch: 1, Batch: 3200, Loss: 7.6803
# INFO:__main__:Epoch: 1, Train Loss: 8.0308
# INFO:__main__:Epoch: 2, Batch: 0, Loss: 7.9280
# INFO:__main__:Epoch: 2, Batch: 100, Loss: 8.0218
# INFO:__main__:Epoch: 2, Batch: 200, Loss: 7.4299
# INFO:__main__:Epoch: 2, Batch: 300, Loss: 7.6834
# INFO:__main__:Epoch: 2, Batch: 400, Loss: 7.9417
# INFO:__main__:Epoch: 2, Batch: 500, Loss: 8.1560
# INFO:__main__:Epoch: 2, Batch: 600, Loss: 8.1834
# INFO:__main__:Epoch: 2, Batch: 700, Loss: 7.4340
# INFO:__main__:Epoch: 2, Batch: 800, Loss: 7.5352
# INFO:__main__:Epoch: 2, Batch: 900, Loss: 7.3506
# INFO:__main__:Epoch: 2, Batch: 1000, Loss: 8.4691
# INFO:__main__:Epoch: 2, Batch: 1100, Loss: 7.2100
# INFO:__main__:Epoch: 2, Batch: 1200, Loss: 7.0645
# INFO:__main__:Epoch: 2, Batch: 1300, Loss: 8.3058
# INFO:__main__:Epoch: 2, Batch: 1400, Loss: 7.4461
# INFO:__main__:Epoch: 2, Batch: 1500, Loss: 8.6492
# INFO:__main__:Epoch: 2, Batch: 1600, Loss: 8.3131
# INFO:__main__:Epoch: 2, Batch: 1700, Loss: 7.4070
# INFO:__main__:Epoch: 2, Batch: 1800, Loss: 7.9152
# INFO:__main__:Epoch: 2, Batch: 1900, Loss: 7.6580
# INFO:__main__:Epoch: 2, Batch: 2000, Loss: 7.6163
# INFO:__main__:Epoch: 2, Batch: 2100, Loss: 7.4411
# INFO:__main__:Epoch: 2, Batch: 2200, Loss: 7.4287
# INFO:__main__:Epoch: 2, Batch: 2300, Loss: 7.3525
# INFO:__main__:Epoch: 2, Batch: 2400, Loss: 8.1654
# INFO:__main__:Epoch: 2, Batch: 2500, Loss: 7.5760
# INFO:__main__:Epoch: 2, Batch: 2600, Loss: 7.9597
# INFO:__main__:Epoch: 2, Batch: 2700, Loss: 8.3122
# INFO:__main__:Epoch: 2, Batch: 2800, Loss: 7.7312
# INFO:__main__:Epoch: 2, Batch: 2900, Loss: 7.7101
# INFO:__main__:Epoch: 2, Batch: 3000, Loss: 7.8280
# INFO:__main__:Epoch: 2, Batch: 3100, Loss: 7.3856
# INFO:__main__:Epoch: 2, Batch: 3200, Loss: 7.5972
# INFO:__main__:Epoch: 2, Train Loss: 7.7659
# INFO:__main__:Epoch: 3, Batch: 0, Loss: 7.7111
# INFO:__main__:Epoch: 3, Batch: 100, Loss: 6.8542
# INFO:__main__:Epoch: 3, Batch: 200, Loss: 6.7959
# INFO:__main__:Epoch: 3, Batch: 300, Loss: 7.3704
# INFO:__main__:Epoch: 3, Batch: 400, Loss: 7.7822
# INFO:__main__:Epoch: 3, Batch: 500, Loss: 7.7043
# INFO:__main__:Epoch: 3, Batch: 600, Loss: 7.0214
# INFO:__main__:Epoch: 3, Batch: 700, Loss: 7.9044
# INFO:__main__:Epoch: 3, Batch: 800, Loss: 6.7533
# INFO:__main__:Epoch: 3, Batch: 900, Loss: 7.2137
# INFO:__main__:Epoch: 3, Batch: 1000, Loss: 7.6074
# INFO:__main__:Epoch: 3, Batch: 1100, Loss: 7.3914
# INFO:__main__:Epoch: 3, Batch: 1200, Loss: 7.9122
# INFO:__main__:Epoch: 3, Batch: 1300, Loss: 7.9522
# INFO:__main__:Epoch: 3, Batch: 1400, Loss: 7.8130
# INFO:__main__:Epoch: 3, Batch: 1500, Loss: 7.4209
# INFO:__main__:Epoch: 3, Batch: 1600, Loss: 7.6301
# INFO:__main__:Epoch: 3, Batch: 1700, Loss: 7.5624
# INFO:__main__:Epoch: 3, Batch: 1800, Loss: 7.8046
# INFO:__main__:Epoch: 3, Batch: 1900, Loss: 7.5441
# INFO:__main__:Epoch: 3, Batch: 2000, Loss: 7.2757
# INFO:__main__:Epoch: 3, Batch: 2100, Loss: 6.9964
# INFO:__main__:Epoch: 3, Batch: 2200, Loss: 7.7953
# INFO:__main__:Epoch: 3, Batch: 2300, Loss: 7.6667
# INFO:__main__:Epoch: 3, Batch: 2400, Loss: 6.9249
# INFO:__main__:Epoch: 3, Batch: 2500, Loss: 8.0797
# INFO:__main__:Epoch: 3, Batch: 2600, Loss: 7.5398
# INFO:__main__:Epoch: 3, Batch: 2700, Loss: 7.5951
# INFO:__main__:Epoch: 3, Batch: 2800, Loss: 7.3751
# INFO:__main__:Epoch: 3, Batch: 2900, Loss: 7.5528
# INFO:__main__:Epoch: 3, Batch: 3000, Loss: 7.8139
# INFO:__main__:Epoch: 3, Batch: 3100, Loss: 7.7676
# INFO:__main__:Epoch: 3, Batch: 3200, Loss: 7.2961
# INFO:__main__:Epoch: 3, Train Loss: 7.5183
# INFO:__main__:Epoch: 4, Batch: 0, Loss: 7.2551
# INFO:__main__:Epoch: 4, Batch: 100, Loss: 7.5175
# INFO:__main__:Epoch: 4, Batch: 200, Loss: 7.3766
# INFO:__main__:Epoch: 4, Batch: 300, Loss: 7.4121
# INFO:__main__:Epoch: 4, Batch: 400, Loss: 7.5376
# INFO:__main__:Epoch: 4, Batch: 500, Loss: 7.3273
# INFO:__main__:Epoch: 4, Batch: 600, Loss: 7.8443
# INFO:__main__:Epoch: 4, Batch: 700, Loss: 7.1851
# INFO:__main__:Epoch: 4, Batch: 800, Loss: 6.8230
# INFO:__main__:Epoch: 4, Batch: 900, Loss: 7.7649
# INFO:__main__:Epoch: 4, Batch: 1000, Loss: 7.1446
# INFO:__main__:Epoch: 4, Batch: 1100, Loss: 7.3338
# INFO:__main__:Epoch: 4, Batch: 1200, Loss: 7.2055
# INFO:__main__:Epoch: 4, Batch: 1300, Loss: 7.3739
# INFO:__main__:Epoch: 4, Batch: 1400, Loss: 7.7352
# INFO:__main__:Epoch: 4, Batch: 1500, Loss: 6.9443
# INFO:__main__:Epoch: 4, Batch: 1600, Loss: 7.4194
# INFO:__main__:Epoch: 4, Batch: 1700, Loss: 7.5091
# INFO:__main__:Epoch: 4, Batch: 1800, Loss: 7.4749
# INFO:__main__:Epoch: 4, Batch: 1900, Loss: 6.4610
# INFO:__main__:Epoch: 4, Batch: 2000, Loss: 7.0805
# INFO:__main__:Epoch: 4, Batch: 2100, Loss: 7.1690
# INFO:__main__:Epoch: 4, Batch: 2200, Loss: 6.5889
# INFO:__main__:Epoch: 4, Batch: 2300, Loss: 6.5143
# INFO:__main__:Epoch: 4, Batch: 2400, Loss: 6.6763
# INFO:__main__:Epoch: 4, Batch: 2500, Loss: 6.9185
# INFO:__main__:Epoch: 4, Batch: 2600, Loss: 6.6294
# INFO:__main__:Epoch: 4, Batch: 2700, Loss: 7.9898
# INFO:__main__:Epoch: 4, Batch: 2800, Loss: 7.6402
# INFO:__main__:Epoch: 4, Batch: 2900, Loss: 7.2821
# INFO:__main__:Epoch: 4, Batch: 3000, Loss: 7.8859
# INFO:__main__:Epoch: 4, Batch: 3100, Loss: 7.6805
# INFO:__main__:Epoch: 4, Batch: 3200, Loss: 7.7073
# INFO:__main__:Epoch: 4, Train Loss: 7.2964
# INFO:__main__:Epoch: 5, Batch: 0, Loss: 6.5469
# INFO:__main__:Epoch: 5, Batch: 100, Loss: 7.5864
# INFO:__main__:Epoch: 5, Batch: 200, Loss: 7.0038
# INFO:__main__:Epoch: 5, Batch: 300, Loss: 7.5041
# INFO:__main__:Epoch: 5, Batch: 400, Loss: 7.1467
# INFO:__main__:Epoch: 5, Batch: 500, Loss: 7.9386
# INFO:__main__:Epoch: 5, Batch: 600, Loss: 7.2187
# INFO:__main__:Epoch: 5, Batch: 700, Loss: 6.1632
# INFO:__main__:Epoch: 5, Batch: 800, Loss: 6.8775
# INFO:__main__:Epoch: 5, Batch: 900, Loss: 7.1596
# INFO:__main__:Epoch: 5, Batch: 1000, Loss: 7.6632
# INFO:__main__:Epoch: 5, Batch: 1100, Loss: 7.3918
# INFO:__main__:Epoch: 5, Batch: 1200, Loss: 7.1725
# INFO:__main__:Epoch: 5, Batch: 1300, Loss: 7.1278
# INFO:__main__:Epoch: 5, Batch: 1400, Loss: 6.9258
# INFO:__main__:Epoch: 5, Batch: 1500, Loss: 7.4583
# INFO:__main__:Epoch: 5, Batch: 1600, Loss: 7.3277
# INFO:__main__:Epoch: 5, Batch: 1700, Loss: 7.1410
# INFO:__main__:Epoch: 5, Batch: 1800, Loss: 7.4315
# INFO:__main__:Epoch: 5, Batch: 1900, Loss: 6.8235
# INFO:__main__:Epoch: 5, Batch: 2000, Loss: 7.6505
# INFO:__main__:Epoch: 5, Batch: 2100, Loss: 6.6988
# INFO:__main__:Epoch: 5, Batch: 2200, Loss: 7.5888
# INFO:__main__:Epoch: 5, Batch: 2300, Loss: 7.1275
# INFO:__main__:Epoch: 5, Batch: 2400, Loss: 7.4455
# INFO:__main__:Epoch: 5, Batch: 2500, Loss: 7.0141
# INFO:__main__:Epoch: 5, Batch: 2600, Loss: 6.8241
# INFO:__main__:Epoch: 5, Batch: 2700, Loss: 6.6886
# INFO:__main__:Epoch: 5, Batch: 2800, Loss: 7.0801
# INFO:__main__:Epoch: 5, Batch: 2900, Loss: 7.1603
# INFO:__main__:Epoch: 5, Batch: 3000, Loss: 7.1795
# INFO:__main__:Epoch: 5, Batch: 3100, Loss: 7.8542
# INFO:__main__:Epoch: 5, Batch: 3200, Loss: 7.1815
# INFO:__main__:Epoch: 5, Train Loss: 7.1262
# INFO:__main__:Epoch: 6, Batch: 0, Loss: 7.3015
# INFO:__main__:Epoch: 6, Batch: 100, Loss: 7.0626
# INFO:__main__:Epoch: 6, Batch: 200, Loss: 6.9383
# INFO:__main__:Epoch: 6, Batch: 300, Loss: 6.6550
# INFO:__main__:Epoch: 6, Batch: 400, Loss: 6.5261
# INFO:__main__:Epoch: 6, Batch: 500, Loss: 6.7912
# INFO:__main__:Epoch: 6, Batch: 600, Loss: 7.1983
# INFO:__main__:Epoch: 6, Batch: 700, Loss: 6.2924
# INFO:__main__:Epoch: 6, Batch: 800, Loss: 6.4625
# INFO:__main__:Epoch: 6, Batch: 900, Loss: 7.2091
# INFO:__main__:Epoch: 6, Batch: 1000, Loss: 7.2385
# INFO:__main__:Epoch: 6, Batch: 1100, Loss: 6.8855
# INFO:__main__:Epoch: 6, Batch: 1200, Loss: 7.2098
# INFO:__main__:Epoch: 6, Batch: 1300, Loss: 6.9377
# INFO:__main__:Epoch: 6, Batch: 1400, Loss: 6.9034
# INFO:__main__:Epoch: 6, Batch: 1500, Loss: 6.3636
# INFO:__main__:Epoch: 6, Batch: 1600, Loss: 6.9932
# INFO:__main__:Epoch: 6, Batch: 1700, Loss: 7.5258
# INFO:__main__:Epoch: 6, Batch: 1800, Loss: 6.4143
# INFO:__main__:Epoch: 6, Batch: 1900, Loss: 7.0059
# INFO:__main__:Epoch: 6, Batch: 2000, Loss: 7.4050
# INFO:__main__:Epoch: 6, Batch: 2100, Loss: 6.9019
# INFO:__main__:Epoch: 6, Batch: 2200, Loss: 6.9402
# INFO:__main__:Epoch: 6, Batch: 2300, Loss: 7.5225
# INFO:__main__:Epoch: 6, Batch: 2400, Loss: 7.2034
# INFO:__main__:Epoch: 6, Batch: 2500, Loss: 7.3503
# INFO:__main__:Epoch: 6, Batch: 2600, Loss: 6.7247
# INFO:__main__:Epoch: 6, Batch: 2700, Loss: 6.8260
# INFO:__main__:Epoch: 6, Batch: 2800, Loss: 7.1290
# INFO:__main__:Epoch: 6, Batch: 2900, Loss: 6.7596
# INFO:__main__:Epoch: 6, Batch: 3000, Loss: 7.5259
# INFO:__main__:Epoch: 6, Batch: 3100, Loss: 7.1337
# INFO:__main__:Epoch: 6, Batch: 3200, Loss: 7.4302
# INFO:__main__:Epoch: 6, Train Loss: 6.9733
# INFO:__main__:Epoch: 7, Batch: 0, Loss: 7.1934
# INFO:__main__:Epoch: 7, Batch: 100, Loss: 7.2335
# INFO:__main__:Epoch: 7, Batch: 200, Loss: 7.1475
# INFO:__main__:Epoch: 7, Batch: 300, Loss: 6.6472
# INFO:__main__:Epoch: 7, Batch: 400, Loss: 6.3114
# INFO:__main__:Epoch: 7, Batch: 500, Loss: 6.5766
# INFO:__main__:Epoch: 7, Batch: 600, Loss: 7.0456
# INFO:__main__:Epoch: 7, Batch: 700, Loss: 6.6384
# INFO:__main__:Epoch: 7, Batch: 800, Loss: 6.8365
# INFO:__main__:Epoch: 7, Batch: 900, Loss: 6.9825
# INFO:__main__:Epoch: 7, Batch: 1000, Loss: 6.5374
# INFO:__main__:Epoch: 7, Batch: 1100, Loss: 6.8581
# INFO:__main__:Epoch: 7, Batch: 1200, Loss: 7.3083
# INFO:__main__:Epoch: 7, Batch: 1300, Loss: 6.9004
# INFO:__main__:Epoch: 7, Batch: 1400, Loss: 7.0812
# INFO:__main__:Epoch: 7, Batch: 1500, Loss: 7.1898
# INFO:__main__:Epoch: 7, Batch: 1600, Loss: 6.6012
# INFO:__main__:Epoch: 7, Batch: 1700, Loss: 6.2359
# INFO:__main__:Epoch: 7, Batch: 1800, Loss: 7.0259
# INFO:__main__:Epoch: 7, Batch: 1900, Loss: 6.7923
# INFO:__main__:Epoch: 7, Batch: 2000, Loss: 6.9452
# INFO:__main__:Epoch: 7, Batch: 2100, Loss: 6.4224
# INFO:__main__:Epoch: 7, Batch: 2200, Loss: 6.4970
# INFO:__main__:Epoch: 7, Batch: 2300, Loss: 7.5371
# INFO:__main__:Epoch: 7, Batch: 2400, Loss: 6.8822
# INFO:__main__:Epoch: 7, Batch: 2500, Loss: 7.3555
# INFO:__main__:Epoch: 7, Batch: 2600, Loss: 7.5038
# INFO:__main__:Epoch: 7, Batch: 2700, Loss: 6.9552
# INFO:__main__:Epoch: 7, Batch: 2800, Loss: 7.1586
# INFO:__main__:Epoch: 7, Batch: 2900, Loss: 6.2589
# INFO:__main__:Epoch: 7, Batch: 3000, Loss: 6.9011
# INFO:__main__:Epoch: 7, Batch: 3100, Loss: 7.3051
# INFO:__main__:Epoch: 7, Batch: 3200, Loss: 7.0285
# INFO:__main__:Epoch: 7, Train Loss: 6.8336
# INFO:__main__:Epoch: 8, Batch: 0, Loss: 6.0062
# INFO:__main__:Epoch: 8, Batch: 100, Loss: 7.1951
# INFO:__main__:Epoch: 8, Batch: 200, Loss: 5.9181
# INFO:__main__:Epoch: 8, Batch: 300, Loss: 6.4503
# INFO:__main__:Epoch: 8, Batch: 400, Loss: 7.0484
# INFO:__main__:Epoch: 8, Batch: 500, Loss: 6.8636
# INFO:__main__:Epoch: 8, Batch: 600, Loss: 6.7253
# INFO:__main__:Epoch: 8, Batch: 700, Loss: 6.6130
# INFO:__main__:Epoch: 8, Batch: 800, Loss: 6.8114
# INFO:__main__:Epoch: 8, Batch: 900, Loss: 6.5779
# INFO:__main__:Epoch: 8, Batch: 1000, Loss: 6.3530
# INFO:__main__:Epoch: 8, Batch: 1100, Loss: 6.1123
# INFO:__main__:Epoch: 8, Batch: 1200, Loss: 6.8099
# INFO:__main__:Epoch: 8, Batch: 1300, Loss: 6.8443
# INFO:__main__:Epoch: 8, Batch: 1400, Loss: 6.0069
# INFO:__main__:Epoch: 8, Batch: 1500, Loss: 6.9906
# INFO:__main__:Epoch: 8, Batch: 1600, Loss: 6.5995
# INFO:__main__:Epoch: 8, Batch: 1700, Loss: 7.0925
# INFO:__main__:Epoch: 8, Batch: 1800, Loss: 7.3749
# INFO:__main__:Epoch: 8, Batch: 1900, Loss: 6.4187
# INFO:__main__:Epoch: 8, Batch: 2000, Loss: 5.3328
# INFO:__main__:Epoch: 8, Batch: 2100, Loss: 7.0645
# INFO:__main__:Epoch: 8, Batch: 2200, Loss: 6.0289
# INFO:__main__:Epoch: 8, Batch: 2300, Loss: 7.0455
# INFO:__main__:Epoch: 8, Batch: 2400, Loss: 6.8785
# INFO:__main__:Epoch: 8, Batch: 2500, Loss: 7.1636
# INFO:__main__:Epoch: 8, Batch: 2600, Loss: 6.4231
# INFO:__main__:Epoch: 8, Batch: 2700, Loss: 6.9064
# INFO:__main__:Epoch: 8, Batch: 2800, Loss: 6.6428
# INFO:__main__:Epoch: 8, Batch: 2900, Loss: 7.0874
# INFO:__main__:Epoch: 8, Batch: 3000, Loss: 7.1544
# INFO:__main__:Epoch: 8, Batch: 3100, Loss: 6.8593
# INFO:__main__:Epoch: 8, Batch: 3200, Loss: 6.8481
# INFO:__main__:Epoch: 8, Train Loss: 6.7012
# INFO:__main__:Epoch: 9, Batch: 0, Loss: 6.8302
# INFO:__main__:Epoch: 9, Batch: 100, Loss: 6.1315
# INFO:__main__:Epoch: 9, Batch: 200, Loss: 6.5926
# INFO:__main__:Epoch: 9, Batch: 300, Loss: 6.7385
# INFO:__main__:Epoch: 9, Batch: 400, Loss: 6.5300
# INFO:__main__:Epoch: 9, Batch: 500, Loss: 6.4938
# INFO:__main__:Epoch: 9, Batch: 600, Loss: 6.3662
# INFO:__main__:Epoch: 9, Batch: 700, Loss: 6.9013
# INFO:__main__:Epoch: 9, Batch: 800, Loss: 6.4986
# INFO:__main__:Epoch: 9, Batch: 900, Loss: 6.1887
# INFO:__main__:Epoch: 9, Batch: 1000, Loss: 7.0481
# INFO:__main__:Epoch: 9, Batch: 1100, Loss: 6.6534
# INFO:__main__:Epoch: 9, Batch: 1200, Loss: 6.9211
# INFO:__main__:Epoch: 9, Batch: 1300, Loss: 6.6684
# INFO:__main__:Epoch: 9, Batch: 1400, Loss: 5.7875
# INFO:__main__:Epoch: 9, Batch: 1500, Loss: 5.8577
# INFO:__main__:Epoch: 9, Batch: 1600, Loss: 6.2443
# INFO:__main__:Epoch: 9, Batch: 1700, Loss: 7.0212
# INFO:__main__:Epoch: 9, Batch: 1800, Loss: 7.1898
# INFO:__main__:Epoch: 9, Batch: 1900, Loss: 6.9186
# INFO:__main__:Epoch: 9, Batch: 2000, Loss: 6.7739
# INFO:__main__:Epoch: 9, Batch: 2100, Loss: 6.8230
# INFO:__main__:Epoch: 9, Batch: 2200, Loss: 6.8068
# INFO:__main__:Epoch: 9, Batch: 2300, Loss: 6.5440
# INFO:__main__:Epoch: 9, Batch: 2400, Loss: 6.7306
# INFO:__main__:Epoch: 9, Batch: 2500, Loss: 7.1096
# INFO:__main__:Epoch: 9, Batch: 2600, Loss: 6.9564
# INFO:__main__:Epoch: 9, Batch: 2700, Loss: 6.7769
# INFO:__main__:Epoch: 9, Batch: 2800, Loss: 6.7985
# INFO:__main__:Epoch: 9, Batch: 2900, Loss: 6.1072
# INFO:__main__:Epoch: 9, Batch: 3000, Loss: 5.8204
# INFO:__main__:Epoch: 9, Batch: 3100, Loss: 6.2196
# INFO:__main__:Epoch: 9, Batch: 3200, Loss: 6.5762
# INFO:__main__:Epoch: 9, Train Loss: 6.5750

# %%
# Load tokenizer
with open('tokenizer.pkl', 'rb') as f:
    tokenizer = pickle.load(f)

# Set VOCAB_SIZE to match tokenizer
VOCAB_SIZE = len(tokenizer.word_index) + 1

def load_model_from_checkpoint(epoch=9):
    encoder = Encoder(VOCAB_SIZE, EMBEDDING_DIM, HIDDEN_DIM).to(DEVICE)
    decoder = Decoder(VOCAB_SIZE, EMBEDDING_DIM, HIDDEN_DIM).to(DEVICE)
    model = Seq2Seq(encoder, decoder).to(DEVICE)
    checkpoint_path = f'arabic_summarizer_epoch_{epoch}.pt'
    model.load_state_dict(torch.load(checkpoint_path, map_location=DEVICE))
    model.eval()
    return model

model = load_model_from_checkpoint(epoch=9)
# Out:
# C:\Users\Azooo\AppData\Local\Temp\ipykernel_5608\925211481.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(checkpoint_path, map_location=DEVICE))

# %%
def generate_summary(model, tokenizer, text, max_length=32):
    model.eval()
    text = normalize_arabic(text)
    text_seq = tokenizer.texts_to_sequences([text])[0]
    text_padded = pad_sequences([text_seq], maxlen=MAX_TEXT_LEN, padding='post')
    text_tensor = torch.tensor(text_padded, dtype=torch.long).to(DEVICE)
    sos_idx = tokenizer.word_index.get('<sos>', 2)
    eos_idx = tokenizer.word_index.get('<eos>', 3)
    decoder_input = torch.tensor([[sos_idx]], dtype=torch.long).to(DEVICE)
    with torch.no_grad():
        _, (hidden, cell) = model.encoder(text_tensor)
    summary = []
    for _ in range(max_length):
        output, hidden, cell = model.decoder(decoder_input, hidden, cell)
        predicted = output.argmax(2)
        pred_idx = predicted.item()
        if pred_idx == eos_idx:
            break
        summary.append(pred_idx)
        decoder_input = predicted
    idx2word = {v: k for k, v in tokenizer.word_index.items()}
    summary_words = [idx2word.get(idx, '') for idx in summary]
    return ' '.join(summary_words)
"ss"

# %%
test_text = """

تعتبر التغذية السليمة أساس الصحة الجيدة. يجب أن يحتوي النظام الغذائي اليومي على مجموعة متنوعة من الأطعمة المغذية. الخضروات والفواكه الطازجة توفر الفيتامينات والمعادن الضرورية للجسم. البروتينات الموجودة في اللحوم والأسماك والبقوليات تساعد في بناء العضلات وإصلاح الأنسجة.

من المهم تناول وجبات منتظمة وتجنب الوجبات السريعة الغنية بالدهون والسكريات. شرب الماء بكميات كافية يساعد في الحفاظ على رطوبة الجسم وتحسين عملية الهضم. يجب أيضاً التقليل من المشروبات الغازية والعصائر المحلاة.

تناول وجبة الإفطار يعتبر من أهم العادات الصحية. فهي تمد الجسم بالطاقة اللازمة لبدء اليوم بنشاط. من المهم أيضاً تناول وجبات خفيفة صحية بين الوجبات الرئيسية للحفاظ على مستوى الطاقة في الجسم.
"""
summary = generate_summary(model, tokenizer, test_text)
print(f"Generated Summary: {summary}")
# Out:
# Generated Summary: تناول كميه وفيره من الماء تناول تناول من تناول تناول من تناول تناول من تناول
